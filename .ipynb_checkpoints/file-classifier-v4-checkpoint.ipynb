# %%
#we import the libraries we will use
import glob
import os
import os.path, time
import shutil
import sys
import filecmp

#we sort everything inside our folder by date and we print it to see what do we have inside
def sort_time(to_be_sorted):
    to_be_sorted.sort(key=os.path.getctime)
    print("\n \nThe following files are inside the folder: \n \n - "+  "\n - " .join(to_be_sorted) + "\n")

fileNames = []
def filesNames(allFiles):
    for a in allFiles:
        fileNames.append(a[a.rfind("\\") +1:])

    
#We create a list with all month + year, so if there is 
#any already existent folder with that name, the script does not
#move it
years =[]

for y in range(1995, 2100,1):
    years.append(y)

import calendar
months = []

for num in range(1,13,1):
    month = calendar.month_abbr[num]
    months.append(month)


monthANDyear = []

for m in months:
    for y in years:
        monthANDyear.append(m + ' ' + str(y))    

#Where is the file located ? This will give us the whole path
cwd = os.getcwd()

#Get me all of the files, including the ones inside the folders, but just the ones with the extension defined in formats
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = []
    # Iterate over all the entries
    for entry in listOfFile:
        for k in formats:
            if entry[1:].split(".")[len(entry[1:].split("."))-1] in formats[k]:
            # Create full path
                fullPath = os.path.join(dirName, entry)
                # If entry is a directory then get the list of files in this directory 
                if os.path.isdir(fullPath):
                    allFiles = allFiles + getListOfFiles(fullPath)
                else:
                    allFiles.append(fullPath)

    return allFiles


filesDatesType = {}

#extract the date and define which type of file is it, video or image ?
def giveFileDateType(to_be_extracted):
   
    for file in to_be_extracted:
        predate = time.ctime(os.path.getmtime(file))
        date = predate[4:7] +' '+ predate[20:26]
        uniqueDates.add(date)
        #If the file extension is present in the formats list, then this file will be "video"
        if file[1:].split(".")[len(file[1:].split("."))-1] in formats["video"]:
            filesDatesType.update({file: (date, "video")})
        #Same as before but "image"    
        elif file[1:].split(".")[len(file[1:].split("."))-1] in formats["image"]:
            filesDatesType.update({file: (date, "image")})    
    return(filesDatesType)
            

                
#the following function creates folders
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)

    except OSError:
        print ('Error: Creating directory. ' +  directory)   
                

#El objetivo de esto es crear carpetas basado en si es JPG o bien video        
def createFolders(filesDatesType):
    for f in filesDatesType:
        createFolder("./Output/" +filesDatesType[f][0])
        createFolder("./Output/"+filesDatesType[f][0]+"/" +filesDatesType[f][1])  
    print("\n"+ "\n" + "The folders for the dates were created. Inside each folder you will find the folder of the file type, that is to say, videos and/or images")    

def move(filesDatesType):    
    for f in filesDatesType:
        shutil.copy(os.path.realpath(f), os.path.realpath("./Output/" +filesDatesType[f][0] + "/" +filesDatesType[f][1]))
    print("\n" +"The following files were moved: \n")
    for f in filesDatesType:
        print(f[1:].split("\\")[len(f[1:].split("\\"))-1])

#This function will search for files inside folders and folders inside folders
#it will get all files and will copy them in the main folder

notIncluded = []
renamed = []
excluded = ["ipynb","DS"]
def getAllFilesinFolders(path):
    if os.path.isfile(path):
        file = path[path.rfind("/")+1:]
        if file not in os.listdir("."):
            shutil.copy(path,".")
        else:
            fileInMainDir="./"+file
            if filecmp.cmp(path,fileInMainDir):
                notIncluded.append(" - "+file+ "\n") 
            else:
                file2= "c"+file
                
                while file2 in os.listdir("."):
                      file2 = "c"+file2
                shutil.copy(path,"./"+file2)
                renamed.append(" - "+file+" " + "-->"+ " -"+file2+"\n")
            
    elif os.path.isdir(path):
        for item in os.listdir(path):
            if not any(string in item for string in excluded):
                pathitem = path+"/"+item
                getAllFilesinFolders(pathitem)
    else:
        print("It is a special file (socket, FIFO, device file)")

# %%
print("Script starting... \n")

#which formats need to be checked ?
videoExtensions= ("swf","qt","flv", "webm","wmv", "wma", "asf","ogg", "oga", "ogv", "ogx","3gp", "3gp2", "3g2", "3gpp", "3gpp2","mp4", "m4a", "m4v", "f4v", "f4a", "m4b", "m4r", "f4b", "mov","avi")
imageExtensions =("jpg", "jpeg", "jpe", "jif", "jfif", "jfi","png","gif","webp","tiff","tif","psd","raw", "arw", "cr2", "nrw", "k25","bmp", "dib","heif", "heic","ind", "indd", "indt","jp2", "j2k", "jpf", "jpx", "jpm", "mj2","svg", "svgz"    )
formats = { "video": videoExtensions, "image": imageExtensions }

print("This script will only consider the following file extensions: \n")

for k,v in formats.items():
    print(" - " +str(k)+" " +str(v) + "\n")
    
print("\n If you want to add other ")
# Out:
# Script starting...
#
# This script will only consider the following file extensions:
#
#  - video ('mpg', 'mp4', 'avi')
#
#  - image ('jpg', 'jpeg', 'png')

# %%
#Copies all files inside folders to the main folder where the script will worl
getAllFilesinFolders(".")
print("\nThe following files won't be included in the script since they are duplicated, only one of them will be moved.\n")
print("".join(notIncluded)+"\n") 
print("\nThe following files had the same name, but different content. They were renamed, adding a -c- in front: \n")
print("".join(renamed)+"\n")

#Gets all the files
allFiles = getListOfFiles(cwd)

#We define the variables that will be used in our functions. They are now empty
uniqueDates = set()

#if the list ist empty, it means there are no files to work on, then we abort the script
if not allFiles:
    sys.exit("\n NO FILES FOUND! Please add files inside the folder. Otherwise what do you actually want to classify ? \n")

filesNames(allFiles)
sort_time(fileNames)    
    
#We extract the date from the files
giveFileDateType(allFiles)


#Creates the dates and file type folders
createFolders(filesDatesType)

#It moves the files to it respective folders
move(filesDatesType)

print(" \n - - - - - - - - - - - - - SCRIPT ENDED - - - - - - - - - - - - - ")
# Out:
# Script starting...
#
#
# The following files won't be included in the script since they are duplicated, only one of them will be moved.
#
#  - 2.png
#  - 2.png
#  - lalalala.png
#  - ccccccccccccc2.png
#  - cccccccccccccc2.png
#  - ccccccccccccccc2.png
#  - cccccccccccccccc2.png
#  - ccccccccccccccccc2.png
#  - cccccccccccccccccc2.png
#  - file-classifier-v4.html
#  - file-classifier-v4.py
#  - lalalala.png
#  - 2.png
#  - c2.png
#  - ccccccccccccc2.png
#  - cccccccccccccc2.png
#  - ccccccccccccccc2.png
#  - cccccccccccccccc2.png
#  - ccccccccccccccccc2.png
#  - cccccccccccccccccc2.png
#  - lalalala.png
#  - README.md
#  - config
#  - description
#  - FETCH_HEAD
#  - HEAD
#  - applypatch-msg.sample
#  - commit-msg.sample
#  - fsmonitor-watchman.sample
#  - post-update.sample
#  - pre-applypatch.sample
#  - pre-commit.sample
#  - pre-push.sample
#  - pre-rebase.sample
#  - pre-receive.sample
#  - prepare-commit-msg.sample
#  - update.sample
#  - index
#  - exclude
#  - master
#  - 010a8023be01e0cda821e722bdd702be8d0179
ccccccccccccccccccc2.png
#  - ccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccccccc2.png
#  - cccHEAD
#  - ccHEAD
#  - cHEAD
#  - cmaster
#  - commit-msg.sample
#  - config
#  - d87abbf09dc88d05e4dfc36764106998865565
#  - dbf3b84b9ddc5e65038b24ed8193dd37bb8ace
#  - description
#  - e674d8873377a691c82478a88d7cef6d06e2bf
#  - ed27f73c2500bff8d015ecc240f31a69497d32
#  - exclude
#  - f8a7441f9f413def13c8d164963b7d94209217
#  - FETCH_HEAD
#  - file-classifier-v4.html
#  - file-classifier-v4.py
#  - fsmonitor-watchman.sample
#  - HEAD
#  - index
#  - lalalala.png
#  - master
#  - 2.png
#  - c2.png
#  - cc2.png
#  - ccc2.png
#  - cccc2.png
#  - ccccc2.png
#  - cccccc2.png
#  - ccccccc2.png
#  - cccccccc2.png
#  - ccccccccc2.png
#  - cccccccccc2.png
#  - ccccccccccc2.png
#  - cccccccccccc2.png
#  - ccccccccccccc2.png
#  - cccccccccccccc2.png
#  - ccccccccccccccc2.png
#  - cccccccccccccccc2.png
#  - ccccccccccccccccc2.png
#  - cccccccccccccccccc2.png
#  - ccccccccccccccccccc2.png
#  - cccccccccccccccccccc2.png
#  - ccccccccccccccccccccc2.png
#  - cccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccccccc2.png
#  - lalalala.png
#  - packed-refs
#  - post-update.sample
#  - pre-applypatch.sample
#  - pre-commit.sample
#  - pre-push.sample
#  - pre-rebase.sample
#  - pre-receive.sample
#  - prepare-commit-msg.sample
#  - README.md
#  - update.sample
#  - config
#  - description
#  - FETCH_HEAD
#  - HEAD
#  - applypatch-msg.sample
#  - commit-msg.sample
#  - fsmonitor-watchman.sample
#  - post-update.sample
#  - pre-applypatch.sample
#  - pre-commit.sample
#  - pre-push.sample
#  - pre-rebase.sample
#  - pre-receive.sample
#  - prepare-commit-msg.sample
#  - update.sample
#  - index
#  - exclude
#  - master
#  - 010a8023be01e0cda821e722bdd702be8d0179
#  - b99798277889e32f7eead5d5056ac2930b8f07
#  - 7b8bf5d332c419b9e9dee7ce149e9bf379a302
#  - a68469486cfaedd2196d4edbf75374a3492e3b
#  - d87abbf09dc88d05e4dfc36764106998865565
#  - dbf3b84b9ddc5e65038b24ed8193dd37bb8ace
#  - b00114c52d8efd3591f677d47c53e1eb320fca
#  - 08ddfcf53c02e82d7eee2e57c38e5672ef89f6
#  - 9f8fbac785b7202b62489e49b89b2c042b02ed
#  - 5974216bde4de30ac1b8a873eb7a7499fb4261
#  - f8a7441f9f413def13c8d164963b7d94209217
#  - 62e024ffbb415f5e24a3a8977d9feab1df47b4
#  - 6a6d988a6c9c1640dc96abe424fe9311eaa4a5
#  - ed27f73c2500bff8d015ecc240f31a69497d32
#  - 0fc2e5fdccb487cc78368c35ef31f46306b03a
#  - 93e008db9d80897c85ee96e99a12e1b9b6b09a
#  - 4a6d94681c7aa74d0895ba9a11155e3aafeb46
#  - 2750b2a354dea91a6b2d2ccacd2439a7981965
#  - b56d6ead207efea8d8e30d90d28616f85b04ef
#  - b148d4974f0320e4c38e4f2e40966bd49fc13a
#  - 0674b09c33b127d227a928c98615f1c2648499
#  - 9de29bb2d1d6434b8b29ae775ad8c2e48c5391
ccccccccccccccccccc2.png
#  - ccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccccccccccc2.png
#  - lalalala.png
#  - packed-refs
#  - post-update.sample
#  - pre-applypatch.sample
#  - pre-commit.sample
#  - pre-push.sample
#  - pre-rebase.sample
#  - pre-receive.sample
#  - prepare-commit-msg.sample
#  - README.md
#  - update.sample
#
#
#
# The following files had the same name, but different content. They were renamed:, adding a -c- in front:
#
#  - HEAD --> -cHEAD
#  - HEAD --> -ccHEAD
#  - master --> -cmaster
#  - HEAD --> -cccHEAD
#  - 2.png --> -c2.png
#  - 2.png --> -cc2.png
#  - 2.png --> -ccc2.png
#  - 2.png --> -cccc2.png
#  - cc2.png --> -ccccc2.png
#  - ccc2.png --> -cccccc2.png
#  - cccc2.png --> -ccccccc2.png
#  - ccccc2.png --> -cccccccc2.png
#  - cccccc2.png --> -ccccccccc2.png
#  - ccccccc2.png --> -cccccccccc2.png
#  - cccccccc2.png --> -ccccccccccc2.png
#  - ccccccccc2.png --> -cccccccccccc2.png
#  - cccccccccc2.png --> -ccccccccccccccccccc2.png
#  - ccccccccccc2.png --> -cccccccccccccccccccc2.png
#  - cccccccccccc2.png --> -ccccccccccccccccccccc2.png
#  - ccccccccccccccccccc2.png --> -cccccccccccccccccccccc2.png
#  - cccccccccccccccccccc2.png --> -ccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccc2.png --> -cccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccc2.png --> -ccccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccc2.png --> -cccccccccccccccccccccccccc2.png
#  - cccccccccccccccccccccccc2.png --> -ccccccccccccccccccccccccccc2.png
#  - ccccccccccccccccccccccccc2.png --> -cccccccccccccccccccccccccccc2.png
#  - HEAD --> -ccccHEAD
#  - HEAD --> -cccccHEAD
#  - master --> -ccmaster
#  - HEAD --> -ccccccHEAD
#  - 2.png --> -ccccccccccccccccccccccccccccc2.png
#  - 2.png --> -cccccccccccccccccccccccccccccc2.png
#  - 2.png --> -ccccccccccccccccccccccccccccccc2.png
#  - 2.png --> -cccccccccccccccccccccccccccccccc2.png
#  - HEAD --> -cccccccHEAD
#  - HEAD --> -ccccccccHEAD
#  - master --> -cccmaster
#  - HEAD --> -cccccccccHEAD
#  - 2.png --> -ccccccccccccccccccccccccccccccccc2.png
#  - 2.png --> -cccccccccccccccccccccccccccccccccc2.png
#  - 2.png --> -ccccccccccccccccccccccccccccccccccc2.png
#  - 2.png --> -cccccccccccccccccccccccccccccccccccc2.png
#
#
#
#
# The following files are inside the folder:
#
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/lalalala.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/lalalala.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/lalalala.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/c2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/c2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/c2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccccccccc2.png
#  - /Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccccccccc2.png
#
#
#
# The folders for the dates were created. Inside each folder you will find the folder of the file type, that is to say, videos and/or images
# The following files were moved:
#
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/c2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/lalalala.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/ccccccccccccccccccccccccccccccccccc2.png
# Users/macbook/Documents/MisDocs/Scripts/file-classifier/cccccccccccccccccccccccccccccccccccc2.png
#
#  - - - - - - - - - - - - - SCRIP ENDED - - - - - - - - - - - - -
